# %%
import pandas as pd
pd.read_csv("worldwide_records.csv")
# Out:
#    Customer_Name  Customer_ID Customer Open Date Last Consulted Date  \
# 0         Albert       548785         2014-05-07          2012-02-03
# 1          Alice       254523         2010-11-11          2012-02-03
# 2           Andy       542135         2012-07-08          2012-02-03
# 3         Antony       145879         2013-05-09          2012-02-03
# 4           Babu       654789         2010-12-06          2012-02-03
# 5           Bala       852794         2012-06-08          2012-02-03
# 6          Brown       987654         2012-01-03          2012-02-03
# 7        Charles       654321         2011-06-01          2012-02-03
# 8           Jack       123455         2012-06-09          2012-02-03
# 9          James       123458         2010-02-03          2012-02-03
# 10          John       123459         2010-11-12          2012-02-03
# 11        Joseph       854569         2009-12-12          2012-02-03
# 12           Leo       123456         2011-06-07          2012-02-03
# ...

# %%
import pandas as pd
pd.read_csv("india_records.csv")
# Out:
#   Customer_Name  Customer_ID Customer Open Date Last Consulted Date  \
# 0          Jack       123455         2012-06-09          2012-02-03
# 1         James       123458         2010-02-03          2012-02-03
# 2         Mercy       741852         2008-05-07          2012-02-03
# 3       Prakash       124567         2014-09-07          2012-02-03
# 4        Samson       852963         2010-03-05          2012-02-03
# 5         Sandy       325412         2009-10-12          2012-02-03
# 6         Santa       963321         2011-05-04          2012-02-03
# 7         Viswa       654789         2010-10-12          2012-02-03
#
#   Vaccination Type Doctor Consulted          State Country  Post Code  \
# 0              MVD           Robert      Karnataka   India     123487
# 1              MVD             Paul     TamilNamdu   India     987654
# 2              MVD           Robert      Telangana   India     951687
# 3              MVD             Paul         Kerala   India     654653
# ...

# %%
import pandas as pd
pd.read_csv("germany_records.csv")
# Out:
#   Customer_Name  Customer_ID Customer Open Date Last Consulted Date  \
# 0        Albert       548785         2014-05-07          2012-02-03
# 1        Antony       145879         2013-05-09          2012-02-03
# 2          John       123459         2010-11-12          2012-02-03
# 3           Leo       123456         2011-06-07          2012-02-03
#
#   Vaccination Type Doctor Consulted    State  Country  Post Code  \
# 0              MVD           Robert    Hesse  Germany     656645
# 1              MVD           Robert  Hamburg  Germany     658657
# 2              MVD             Paul   Berlin  Germany     641548
# 3              MVD             Paul   Bermen  Germany     754846
#
#   Date Of Birth Active Customer
# 0    1994-08-08               A
# 1    1984-07-06               A
# 2    1995-08-11               A
# 3    1994-12-12               A

# %%
import pandas as pd
pd.read_csv("usa_records.csv")
# Out:
#   Customer_Name  Customer_ID Customer Open Date Last Consulted Date  \
# 0         Alice       254523         2010-11-11          2012-02-03
# 1          Andy       542135         2012-07-08          2012-02-03
# 2          Babu       654789         2010-12-06          2012-02-03
# 3          Bala       852794         2012-06-08          2012-02-03
# 4         Olive       856746         2010-09-15          2012-02-03
# 5        Robert       123457         2010-04-06          2012-02-03
# 6           Sam       794613         2014-11-08          2012-02-03
# 7        Stella       126548         2010-03-06          2012-02-03
#
#   Vaccination Type Doctor Consulted     State Country  Post Code  \
# 0              MVD            Peter   Arizona     USA     785489
# 1              MVD             Paul     Maine     USA     452852
# 2              MVD            Peter  Colorado     USA     621654
# 3              MVD             Rose    Hawaii     USA     246865
# ...

# %%
import pandas as pd
pd.read_csv("france_records.csv")
# Out:
#   Customer_Name  Customer_ID Customer Open Date Last Consulted Date  \
# 0         Brown       987654         2012-01-03          2012-02-03
# 1       Charles       654321         2011-06-01          2012-02-03
# 2        Joseph       854569         2009-12-12          2012-02-03
# 3       Mr.Bean       854123         2011-01-02          2012-02-03
# 4          Prem       126581         2015-09-07          2012-02-03
# 5          Rose       123789         2012-08-07          2012-02-03
#
#   Vaccination Type Doctor Consulted       State Country  Post Code  \
# 0              MVD           Robert      Guinaa  France     654213
# 1              MVD             Rose     Moyotte  France     785423
# 2              MVD             Rose  Martinique  France     542159
# 3              MVD             Paul       Corse  France     641602
# 4              MVD            Peter      Centre  France     325324
# 5              MVD            Peter      Alsace  France     652651
#
# ...
